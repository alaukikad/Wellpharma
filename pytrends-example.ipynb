# %%
from pytrends.request import TrendReq

# %%
pytrend = TrendReq(hl = 'en-US', tz = 360)

# %%
pytrend.build_payload(kw_list = ["ebola","measles","flu","disease"], timeframe='all')

# %%
iot = pytrend.interest_over_time()

# %%
ior=pytrend.interest_by_region(resolution='DMA', inc_low_vol=True, inc_geo_code=False)

# %%
ior
# Out:
#                                          ebola  measles  flu  disease
# geoName
# Abilene-Sweetwater TX                        5        2   26       67
# Ain                                         18        0   28       54
# Aisne                                       35        0    0       65
# Albany GA                                    5        2   25       68
# Albany-Schenectady-Troy NY                   5        2   24       69
# Albuquerque-Santa Fe NM                      7        2   27       64
# Alexandria LA                                6        2   27       65
# Allier                                      21        0    0       79
# Alpena MI                                    6        2   24       68
# Alpes-Maritimes                             12        4   20       64
# Alpes-de-Haute-Provence                      0        0    0        0
# Amarillo TX                                  7        2   27       64
# Anchorage AK                                 8        3   25       64
# Ardeche                                      0        0    0        0
# Ardennes                                   100        0    0        0
# Ariege                                       0        0    0        0
# Atlanta GA                                   7        2   26       65
# Aube                                        24        0   32       44
# Aude                                        11        0   20       69
# Augusta GA                                  19        2   22       57
# Austin TX                                    8        2   30       60
# Aveyron                                     20        0    0       80
# Bakersfield CA                               7        3   25       65
# Baltimore MD                                 6        2   24       68
# Bangor ME                                    6        2   20       72
# Bas-Rhin                                    17        5   19       59
# Baton Rouge LA                               7        2   27       64
# Beaumont-Port Arthur TX                      6        3   27       64
# Bend OR                                      5        4   26       65
# Billings, MT                                 6        2   24       68
# ...                                        ...      ...  ...      ...
# Tri-Cities TN-VA                             5        1   28       66
# Tucson (Sierra Vista) AZ                     6        2   25       67
# Tulsa OK                                     7        2   29       62
# Twin Falls ID                                6        3   23       68
# Tyler-Longview(Lufkin & Nacogdoches) TX      8        2   26       64
# Utica NY                                     6        2   22       70
# Val-d'Oise                                  21        6   24       49
# Val-de-Marne                                17        4   17       62
# Var                                         20        4   22       54
# Vaucluse                                    23        0    0       77
# Vendee                                      29        0   22       49
# Victoria TX                                  7        2   30       61
# Vienne                                      17        0   24       59
# Vosges                                       0        0    0        0
# Waco-Temple-Bryan TX                        10        2   25       63
# Washington DC (Hagerstown MD)               10        2   26       62
# Watertown NY                                 5        2   23       70
# Wausau-Rhinelander WI                        5        2   22       71
# West Palm Beach-Ft. Pierce FL                6        2   24       68
# Wheeling WV-Steubenville OH                  4        2   23       71
# Wichita Falls TX & Lawton OK                 6        2   27       65
# Wichita-Hutchinson KS                        9        2   24       65
# Wilkes Barre-Scranton PA                     5        2   23       70
# Wilmington NC                                5        2   27       66
# Yakima-Pasco-Richland-Kennewick WA           6        3   25       66
# Yonne                                        0        0    0        0
# Youngstown OH                                6        2   24       68
# Yuma AZ-El Centro CA                         8        3   23       66
# Yvelines                                    20        9   21       50
# Zanesville OH                                5        1   23       71
#
# [306 rows x 4 columns]
